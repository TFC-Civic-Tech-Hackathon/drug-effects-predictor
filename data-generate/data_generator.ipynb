# %%
from faker import Faker
import pandas as pd
import random

fake = Faker()

def generate_patient_record():
    name = fake.name()
    age = random.randint(4, 90)
    if age < 18:
        height = random.randint(100, 150)  # Height between 100-150 cm for age below 18
        weight = random.randint(30, 50)      # Weight less than 50 kg for age below 18
    else:
        height = random.randint(150, 200)  # Height between 150-200 cm for age 18 and above
        weight = random.randint(40, 120)   # in kilograms
    
    gender = random.choice(['Male', 'Female'])
    
    if gender == 'Male':
        pregnancy = 'No'
    else:
        pregnancy = random.choice(['Yes', 'No'])
    
    past_medical_conditions = random.choice(["Acne", "Asthama", "Cancer", "Covid19", "Diabetes(type 1)", "Diabetes(type 2)", "Allergies", "Depression", "Hayfever", "Stroke", "Colds & Flu", "Hypertension"])  # Generating a random sentence for past medical conditions
    return {
        'Name': name,
        'Age': age,
        'Gender': gender,
        'Height(cm)': height,
        'Weight(kg)': weight,
        'Pregnancy': pregnancy,
        'Past Medical Conditions': past_medical_conditions
    }

def generate_patient_records(num_records=10):
    records = []
    for _ in range(num_records):
        records.append(generate_patient_record())
    return records

# Generating 10 patient records
patient_records = generate_patient_records(2000)

df = pd.DataFrame(patient_records)

# %%
df
# Out:
#                    Name  Age  Gender  Height(cm)  Weight(kg) Pregnancy  \
# 0        Ashley Roberts   85    Male         174          66        No
# 1        Madeline James   46    Male         155          78        No
# 2     Caitlyn Hernandez   78  Female         200         105       Yes
# 3        Kevin Anderson    4    Male         145          44        No
# 4           Mary Bright   17  Female         131          41       Yes
# ...                 ...  ...     ...         ...         ...       ...
# 1995      Scott Barrett   33  Female         164         107       Yes
# 1996      Michael Clark   30    Male         159          44        No
# 1997    Samantha Palmer   45    Male         160         115        No
# 1998       Joseph Mayer   72    Male         171          80        No
# 1999    Crystal Winters   79  Female         188          55       Yes
#
#      Past Medical Conditions
# 0                     Cancer
# 1                     Stroke
# 2           Diabetes(type 2)
# 3                   Hayfever
# 4                   Hayfever
# ...                      ...
# 1995                  Cancer
# 1996        Diabetes(type 1)
# 1997            Hypertension
# 1998             Colds & Flu
# 1999                  Stroke
#
# [2000 rows x 7 columns]

# %%
df.to_csv('data/patient_records.csv', index=True)
