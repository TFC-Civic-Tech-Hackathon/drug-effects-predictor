# %%
from faker import Faker
import pandas as pd
import random

fake = Faker()

def generate_patient_record(i):
    id = i
    name = fake.name()
    age = random.randint(4, 90)
    if age < 18:
        height = random.randint(100, 150)  # Height between 100-150 cm for age below 18
        weight = random.randint(30, 50)      # Weight less than 50 kg for age below 18
    else:
        height = random.randint(150, 200)  # Height between 150-200 cm for age 18 and above
        weight = random.randint(40, 120)   # in kilograms
    
    gender = random.choice(['Male', 'Female'])
    
    if gender == 'Male':
        pregnancy = 'No'
    else:
        pregnancy = random.choice(['Yes', 'No'])
    
    past_medical_conditions = random.choice(["Acne", "Asthama", "Cancer", "Covid19", "Diabetes(type 1)", "Diabetes(type 2)", "Allergies", "Depression", "Hayfever", "Stroke", "Colds & Flu", "Hypertension"])  # Generating a random sentence for past medical conditions
    return {
        'Patient ID': id,
        'Name': name,
        'Age': age,
        'Gender': gender,
        'Height(cm)': height,
        'Weight(kg)': weight,
        'Pregnancy': pregnancy,
        'Past Medical Conditions': past_medical_conditions
    }

def generate_patient_records(num_records=10):
    records = []
    for i in range(num_records):
        records.append(generate_patient_record(i))
    return records

# Generating 10 patient records
patient_records = generate_patient_records(2000)

df = pd.DataFrame(patient_records)

# %%
df
# Out:
#       Patient ID              Name  Age  Gender  Height(cm)  Weight(kg)  \
# 0              0  Shawn Richardson   69    Male         194          43
# 1              1      Chad Schultz   46    Male         159          52
# 2              2       Karen Riley   87  Female         152         114
# 3              3       Jose Keller   75    Male         175          89
# 4              4     Gloria Jacobs   61    Male         159          69
# ...          ...               ...  ...     ...         ...         ...
# 1995        1995      Edward Arias   84  Female         187          71
# 1996        1996      Shawn Morris   86  Female         200          82
# 1997        1997         Carl Good   54  Female         158          46
# 1998        1998   Jessica Delgado   47  Female         194          69
# 1999        1999       Julie Riley   53  Female         163          59
#
#      Pregnancy Past Medical Conditions
# 0           No                  Cancer
# 1           No                 Covid19
# 2          Yes        Diabetes(type 1)
# 3           No            Hypertension
# 4           No        Diabetes(type 2)
# ...        ...                     ...
# 1995        No                  Cancer
# 1996        No              Depression
# 1997       Yes               Allergies
# 1998        No        Diabetes(type 1)
# 1999       Yes            Hypertension
#
# [2000 rows x 8 columns]

# %%
df.to_csv('data/patient_records.csv', index=True)

# %%
df.to_json('data/patient_records.json',orient='records')
